# %%
print("Hello World")
# Out:
# Hello World

# %%
myfile = open("test.dat",'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("HelloWorld")
myfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d0eff3714639> in <module>
#       1 myfile = open("test.dat",'w')
# ----> 2 myfile.write(numIn)
#       3 myfile.write("\n")
#       4 myfile.write("HelloWorld")
#       5 myfile.close()
#
# NameError: name 'numIn' is not defined

# %%
import math
import random

for i in range(0,50):
    value = random.uniform(-1,1)
    print(value)
# Out:
# -0.8395233045610764
# -0.4195741364626169
# -0.5977413936089042
# 0.43154922132796547
# -0.21981769836257126
# 0.46009093409439594
# 0.12425168779732298
# 0.15697514535792156
# -0.22347137322875787
# 0.8627607876011896
# -0.41688435373694444
# 0.5379764572264671
# -0.3971317573334576
# 0.8444028089830034
# 0.4421804566435201
# 0.48684912450873497
# 0.9428042910371071
# -0.8998603672684435
# 0.7694324163099127
# 0.5436473721027086
# -0.9692384684266053
# -0.22532204493879648
# 0.0031968996913198655
# -0.6056562980641484
# -0.756466016801526
# -0.9446223106526461
# -0.7561167118682208
# 0.19562984023757535
# 0.17629026161341121
# 0.025249574011512843
# 0.2602903173962161
# 0.0917418323661634
# 0.6154151672242179
# 0.8133188081448786
# 0.1606068863930199
# -0.8115653667950027
# -0.08080815127284824
# 0.408123648199624
# -0.04493949951814247
# 0.1784873879521378
# 0.44831282763927627
# -0.5981488879368828
# 0.7855717286238921
# 0.5321426258674957
# 0.9165862099656807
# -0.4663204046069034
# -0.06258682828276751
# 0.5984246011276877
# -0.4625923853238558
# -0.9145149974405118

# %%
import random

def montecarlo_pi(number_of_shots):
    for i in range(0, number_of_shots):
    x = 1
    y = 1
    return
# Out:
#   File "<ipython-input-8-9d24eed91bce>", line 5
#     x = 1
#     ^
# IndentationError: expected an indented block

# %%
montecarlo_pi(50)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a42e4e91e4af> in <module>
# ----> 1 plt.plot(x, np.sin(x),
#       2     x, np.sin(2 * x))
#       3 plt.show()
#
# NameError: name 'x' is not defined
