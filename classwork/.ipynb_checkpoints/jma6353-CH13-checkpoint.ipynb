# %%
import numpy as np
import matplotlib.pyplot as plt
import time

def naive_matrix_multiplication(A, B):
    n = len(A)
    C = [[0] * n for _ in range(n)]

    for i in range(n):
        for j in range(n):
            for k in range(n):
                C[i][j] += A[i][k] * B[k][j]

    return np.array(C)


sizes = [3]
for _ in range(7):
    sizes.append(sizes[-1] * 2)

naive_times = []
numpy_times = []

for n in sizes:
    A = np.random.rand(n, n)
    B = np.random.rand(n, n)

    start = time.perf_counter()
    C_naive = naive_matrix_multiplication(A, B)
    end = time.perf_counter()
    naive_times.append(end - start)

    start = time.perf_counter()
    C_numpy = np.dot(A, B)
    end = time.perf_counter()
    numpy_times.append(end - start)

    print(f"Matrix size: {n}x{n}")
    print(f"Naive time: {naive_times[-1]:.6f} seconds")
    print(f"Numpy time: {numpy_times[-1]:.6f} seconds")
    print()

matrix_numbers = np.arange(1, 9)

plt.figure(figsize=(8, 5))
plt.plot(matrix_numbers, naive_times, marker='o', label='Naive (custom)')
plt.plot(matrix_numbers, numpy_times, marker='s', label='Optimized (numpy)')
plt.xlabel("Matrix Number")
plt.ylabel("Runtime (seconds)")
plt.title("Naive vs Optimized Matrix Multiplication Runtime")
plt.xticks(matrix_numbers)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Matrix size: 3x3
# Naive time: 0.000063 seconds
# Numpy time: 0.000063 seconds
#
# Matrix size: 6x6
# Naive time: 0.000279 seconds
# Numpy time: 0.000020 seconds
#
# Matrix size: 12x12
# Naive time: 0.002034 seconds
# Numpy time: 0.000019 seconds
#
# Matrix size: 24x24
# Naive time: 0.015989 seconds
# Numpy time: 0.000038 seconds
#
# Matrix size: 48x48
# Naive time: 0.121435 seconds
# Numpy time: 0.000065 seconds
#
# Matrix size: 96x96
# Naive time: 0.987193 seconds
# Numpy time: 0.000463 seconds
#
# Matrix size: 192x192
# Naive time: 8.255196 seconds
# Numpy time: 0.000922 seconds
#
# Matrix size: 384x384
# Naive time: 65.869581 seconds
# Numpy time: 0.004770 seconds

# %%
# AI USAGE DISCLOSURE:
# I used ChatGPT to double check my  syntax and help organize the time
# comparison between the custom matrix function and NumPy's
# multiplication. The matrix multiplication structure and overall idea come
# from the lecture slides.
