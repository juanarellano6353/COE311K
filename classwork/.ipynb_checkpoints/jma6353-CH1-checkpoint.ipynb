# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x))
plt.show()

# %%
plt.plot(x, np.sin(x), 'r-o',
x, np.cos(x), 'g--')
plt.show()

# %%
plt.subplot(2, 2, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), 'g')
plt.subplot(2,2,3)
plt.plot(x, np.e**x, 'h')
v= random.uniform(-1,50)
u= random.uniform(-1,50)
plt.hist(x,u)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-db0536c3cadd> in <module>
#       5 plt.subplot(2,2,3)
#       6 plt.plot(x, np.e**x, 'h')
# ----> 7 v= random.uniform(-1,50)
#       8 u= random.uniform(-1,50)
#       9 plt.hist(x,u)
#
# NameError: name 'random' is not defined

# %%
y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
x= np.linspace(0, 5*np.pi, 25)

plt.hist(X, bins=10)
plt.title("Histogram")
plt.
